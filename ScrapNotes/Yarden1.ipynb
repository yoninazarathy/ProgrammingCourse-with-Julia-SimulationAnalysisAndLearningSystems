# %%
places =["Netherlands",
    "Victoria",
    "Victoria",
    "Queensland",
    "Queensland",
    "Queensland",
    "Queensland",
    "Queensland",
    "Queensland",
    "Queensland",
    "Queensland"]
for x = 1:11
    println("When I was $x I lived in $(places[x])")
end
# Out:
# When I was 1 I lived in Netherlands
# When I was 2 I lived in Victoria
# When I was 3 I lived in Victoria
# When I was 4 I lived in Queensland
# When I was 5 I lived in Queensland
# When I was 6 I lived in Queensland
# When I was 7 I lived in Queensland
# When I was 8 I lived in Queensland
# When I was 9 I lived in Queensland
# When I was 10 I lived in Queensland
# When I was 11 I lived in Queensland

# %%
using Plots  
circle=[(cos(x),sin(x)) for x=0:0.005:3pi]
plot(first.(circle),last.(circle))
