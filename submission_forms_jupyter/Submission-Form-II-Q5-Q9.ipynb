# %% [markdown]
# ### MATH2504 S2, 2024, BigHW Submission
# ### Submission form II of IV

# %% [markdown]
# Student #1 name:
#
# Student #1 ID:
#
# Student #2 name:
#
# Student #2 ID:
#
# GitHub repo:

# %% [markdown]
# ---
#
# **Note: It is expected that this notebook be runnable in the sense that the marker can select "Restart & Run All" and all code cells of solutions will execute. This requires not to have name clashes between solutions.**
#
# ---

# %% [markdown]
# # Solution to [Question 5](https://courses.smp.uq.edu.au/MATH2504/2024/assessment_html/bighw.html#q5)

# %% [markdown]
# ## 5a:

# %%
### Make this a markdown cell and answer 5a here (in place of this comment)

# %% [markdown]
# ## 5b:

# %%
### Answer 5b here (in place of this comment)

# %% [markdown]
# ## 5c:

# %%
### Answer 5c here (in place of this comment)

# %% [markdown]
# ---
#
# *Use this area below as an experimental playground for the question. Feel free to leave some of the experimental code here with your submision. However, it will not be marked or reviewed. Make sure in your submission that if there is any experimental code here then running it does not interfere with running the actual solutions.*
#
# ---

# %% [markdown]
# # Solution to [Question 6](https://courses.smp.uq.edu.au/MATH2504/2024/assessment_html/bighw.html#q6)

# %%
### Answer 6 here (in place of this comment)

# %% [markdown]
# ---
#
# *Use this area below as an experimental playground for the question. Feel free to leave some of the experimental code here with your submision. However, it will not be marked or reviewed. Make sure in your submission that if there is any experimental code here then running it does not interfere with running the actual solutions.*
#
# ---

# %% [markdown]
# # Solution to [Question 7](https://courses.smp.uq.edu.au/MATH2504/2024/assessment_html/bighw.html#q7)

# %% [markdown]
# ## 7a:

# %%
### Make this a markdown cell and answer 7a here (in place of this comment) - perhaps use screenshots as well

# %% [markdown]
# ## 7b:

# %%
### Make this a markdown cell and answer 7b here (in place of this comment) - perhaps use screenshots as well

# %% [markdown]
# ## 7c:

# %%
### Answer 7c here (in place of this comment)

# %% [markdown]
# ## 7d:

# %%
### Make this a markdown cell and answer 7d here (in place of this comment)

# %% [markdown]
# ---
#
# *Use this area below as an experimental playground for the question. Feel free to leave some of the experimental code here with your submision. However, it will not be marked or reviewed. Make sure in your submission that if there is any experimental code here then running it does not interfere with running the actual solutions.*
#
# ---

# %% [markdown]
# # Solution to [Question 8](https://courses.smp.uq.edu.au/MATH2504/2024/assessment_html/bighw.html#q8)

# %% [markdown]
# ## 8a:

# %%
### Answer 8a here (in place of this comment)

# %% [markdown]
# ## 8b:

# %%
### Answer 8b here (in place of this comment)

# %% [markdown]
# ## 8c:

# %%
### Answer 8c here (in place of this comment)

# %% [markdown]
# ## 8d:

# %%
### Answer 8d here (in place of this comment)

# %% [markdown]
# ---
#
# *Use this area below as an experimental playground for the question. Feel free to leave some of the experimental code here with your submision. However, it will not be marked or reviewed. Make sure in your submission that if there is any experimental code here then running it does not interfere with running the actual solutions.*
#
# ---

# %% [markdown]
# # Solution to [Question 9](https://courses.smp.uq.edu.au/MATH2504/2024/assessment_html/bighw.html#q9)

# %% [markdown]
# ## 9a:

# %%
### Answer 9a here (in place of this comment)

# %% [markdown]
# ## 9b:

# %%
### Answer 9b here (in place of this comment)

# %% [markdown]
# ## 9c:

# %%
### Answer 9c here (in place of this comment)

# %% [markdown]
# ## 9d:

# %%
### Make this a markdown cell and answer 9d here (in place of this comment)

# %% [markdown]
# ---
#
# *Use this area below as an experimental playground for the question. Feel free to leave some of the experimental code here with your submision. However, it will not be marked or reviewed. Make sure in your submission that if there is any experimental code here then running it does not interfere with running the actual solutions.*
#
# ---
